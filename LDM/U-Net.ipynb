# %%
import network
model = network.UNet()

# %%
import train
num_epoch = 50
train.run(model, num_epoch)
# Out:
# Initializing Training!
# Epoch 1 Train loss: 7220.20197405134 Train acc 0.7703708835005998
# Epoch 2 Train loss: 1.5105875900813512 Train acc 0.7295460842961906
# Epoch 3 Train loss: 17.613664899553573 Train acc 0.770116804958778
# Epoch 4 Train loss: 1.55958753824234 Train acc 0.7474838870078798
# Epoch 5 Train loss: 1.0219841812338148 Train acc 0.7814616135007517
# Val loss: 0.8837509353955587 val acc: 0.8119494120279948
# Epoch 6 Train loss: 7.435577392578125 Train acc 0.4495909121965292
# Epoch 7 Train loss: 0.9013545385428837 Train acc 0.7768167920532013
# Epoch 8 Train loss: 1.0730735404150826 Train acc 0.7351170706618283
# Epoch 9 Train loss: 0.5997294187545776 Train acc 0.7928778297374856
# Epoch 10 Train loss: 0.46531893951552256 Train acc 0.7997787547636762
# Val loss: 0.42640000333388645 val acc: 0.8266792297363281
# Saved.
# Epoch 11 Train loss: 0.43781294354370665 Train acc 0.7983714775367049
# Epoch 12 Train loss: 0.4327957055398396 Train acc 0.7994594366336182
# ...

# %%
img_path ='/content/U-Net-tutorial/data/test/images'
model_path ='/content/U-Net-tutorial/history/latest.pwf'

src_path ='/content/U-Net-tutorial/data/val/images/27.png'
mask_path ='/content/U-Net-tutorial/result/0.png'

import predict
predict.run(img_path, model_path)

from modules import get_prediction_image
get_prediction_image(src_path, mask_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# generate test prediction
# /content/U-Net-tutorial/src/dataset.py:256: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   img_as_tensor = torch.Tensor(processed_list)
# Finish Prediction!
# <PIL.Image.Image image mode=RGB size=1024x512>
